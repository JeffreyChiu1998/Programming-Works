# %%
# !pip install --force-reinstall ibm_db ibm_db_sa
# !pip install sqlalchemy==1.3.9
# !pip install ipython-sql
# Out:
# ...
#   Using cached ibm_db-3.1.0-cp38-cp38-linux_x86_64.whl
# ...
#   Using cached ibm_db_sa-0.3.7-py3-none-any.whl
# ...
#   Using cached SQLAlchemy-1.4.27-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# ...
#   Using cached greenlet-1.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
# ...
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 1.1.2
#     Uninstalling greenlet-1.1.2:
#       Successfully uninstalled greenlet-1.1.2
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.9
#     Uninstalling SQLAlchemy-1.3.9:
#       Successfully uninstalled SQLAlchemy-1.3.9
#   Attempting uninstall: ibm-db
#     Found existing installation: ibm-db 3.1.0
#     Uninstalling ibm-db-3.1.0:
#       Successfully uninstalled ibm-db-3.1.0
#   Attempting uninstall: ibm-db-sa
#     Found existing installation: ibm-db-sa 0.3.7
#     Uninstalling ibm-db-sa-0.3.7:
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql ibm_db_sa://jgs87061:XZHWSjlRRgzJzri1@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB?security=SSL

# %% [markdown]
# ### Problem 1: Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT COUNT(*) FROM ChicagoCrimeData;
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2: List community areas with per capita income less than 11000.

# %%
# %sql SELECT community_area_name FROM ChicagoCensusData WHERE per_capita_income < 11000;
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [('West Garfield Park',),
#  ('South Lawndale',),
#  ('Fuller Park',),
#  ('Riverdale',)]

# %% [markdown]
# ### Problem 3: List all case numbers for crimes involving minors?

# %%
# %sql SELECT case_number FROM ChicagoCrimeData WHERE description LIKE '%MINOR%';
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# ### Problem 4: List all kidnapping crimes involving a child?(children are not considered minors for the purposes of crime analysis)

# %%
# %sql SELECT * FROM ChicagoCrimeData WHERE primary_type = 'KIDNAPPING' AND description LIKE '%CHILD%';
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [(5276766, 'HN144152', datetime.date(2007, 1, 26), '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 'FALSE', 'FALSE', 1533, 15, 29, 25, '20', 1143050, 1897546, 2007, Decimal('41.87490841'), Decimal('-87.75024931'), '(41.874908413, -87.750249307)')]

# %% [markdown]
# ### Problem 5: What kind of crimes were recorded at schools?

# %%
# %sql SELECT primary_type FROM ChicagoCrimeData WHERE location_description LIKE '%SCHOOL%' GROUP BY primary_type;
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [('ASSAULT',),
#  ('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('CRIMINAL TRESPA',),
#  ('NARCOTICS',),
#  ('PUBLIC PEACE VI',)]

# %% [markdown]
# ### Problem 6: List the average safety score for all types of schools.

# %%
# %sql SELECT "Elementary, Middle, or High School", AVG(safety_score) AS average_safety_score FROM ChicagoPublicSchools GROUP BY "Elementary, Middle, or High School";
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [('ES', 49), ('HS', 49), ('MS', 48)]

# %% [markdown]
# ### Problem 7: List 5 community areas with highest % of households below poverty line.

# %%
# %sql SELECT community_area_name, percent_households_below_poverty FROM ChicagoCensusData ORDER BY percent_households_below_poverty DESC LIMIT 5;
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [('Riverdale', Decimal('56.5')),
#  ('Fuller Park', Decimal('51.2')),
#  ('Englewood', Decimal('46.6')),
#  ('North Lawndale', Decimal('43.1')),
#  ('East Garfield Park', Decimal('42.4'))]

# %% [markdown]
# ### Problem 8: Which community area(number) is most crime prone?

# %%
# %sql SELECT community_area_number, COUNT(*) AS crime_case FROM ChicagoCrimeData GROUP BY community_area_number ORDER BY crime_case DESC LIMIT 1;
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [(25, 43)]

# %% [markdown]
# ### Problem 9: Use a sub-query to find the name of the community area with highest hardship index.

# %%
# %sql SELECT community_area_name FROM ChicagoCensusData WHERE hardship_index=(SELECT MAX(hardship_index) FROM ChicagoCensusData);
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [('Riverdale',)]

# %% [markdown]
# ### Problem 10: Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %sql SELECT community_area_name FROM ChicagoCensusData WHERE community_area_number=(SELECT community_area_number FROM ChicagoCrimeData GROUP BY community_area_number ORDER BY COUNT(ChicagoCrimeData.community_area_number) DESC LIMIT 1);
# Out:
#  * ibm_db_sa://jgs87061:***@1bbf73c5-d84a-4bb0-85b9-ab1a4348f4a4.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:32286/BLUDB
# Done.
# [('Austin',)]
